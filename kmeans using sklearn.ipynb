# %%
#kmeans using sklearn
import pandas as pd
from pandas import DataFrame
import numpy as np
import random as rd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline

data={
    "x":[46, 78 ,91 ,77 ,36, 64 ,67 ,50 ,89 ,47 ,39,  1 , 9, 10, 74, 33, 30, 98 ,26 ,70 ,13 ,78, 99 ,60,
 60, 90, 69, 69 ,94, 68 ,79,  2 ,60 ,30 , 8 ,46 ,21, 57, 60, 88,  1, 26, 30 , 1, 72 ,84, 90, 91,
  1, 92],
    "y":[ 7 ,86, 26 ,60, 40, 32 ,23 , 9 ,31, 59, 40 ,53  ,2 ,40 ,87 ,92, 19 ,57 ,18 , 7, 33, 48 ,20, 37,
  6 ,78 ,98 ,37, 72, 66, 24 ,50 ,90, 45 ,66, 74, 13, 98, 84 ,69 , 4 ,41 ,27 ,80 ,56, 48, 18, 15,
 38, 36]
}

df = DataFrame(data,columns=['x','y'])
  
kmeans = KMeans(n_clusters=3).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['x'], df['y'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[75.23529412 24.94117647]
#  [16.70588235 35.82352941]
#  [69.4375     76.625     ]]
